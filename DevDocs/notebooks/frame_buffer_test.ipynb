# %%
import sys

# %%
# !{sys.executable} -m pip install micropython-framebuf
# Out:
# Collecting micropython-framebuf
#   Downloading micropython-framebuf-0.1.tar.gz (1.0 kB)
# ERROR: micropython-framebuf from https://files.pythonhosted.org/packages/e1/b2/537eef851ccece2ce109c1eeecd4c6e85ba0ce68253541806989d995e4e0/micropython-framebuf-0.1.tar.gz does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
https://github.com/micropython/micropython/blob/master/extmod/modframebuf.c
